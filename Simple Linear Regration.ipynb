# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('2023-12-29T17-38-48.115Z-student_marks.csv')

# %%
df
# Out:
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    195 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
df.isnull().sum()
# Out:
# study_hours      5
# student_marks    0
# dtype: int64

# %%
df = df.fillna(df.study_hours.mean())

# %%
df
# Out:
#      study_hours  student_marks
# 0       6.830000          78.50
# 1       6.560000          76.74
# 2       6.995949          78.68
# 3       5.670000          71.82
# 4       8.670000          84.19
# ..           ...            ...
# 195     7.530000          81.67
# 196     8.560000          84.68
# 197     8.940000          86.75
# 198     6.600000          78.05
# 199     8.350000          83.50
#
# [200 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# study_hours      0
# student_marks    0
# dtype: int64

# %%
plt.scatter(x,y)
plt.xlabel('study_hours')
plt.ylabel('student_marks')
plt.show()

# %%
x = df.drop('student_marks',axis = 1)
y = df.drop('study_hours',axis = 1)

# %%
x
# Out:
#      study_hours
# 0       6.830000
# 1       6.560000
# 2       6.995949
# 3       5.670000
# 4       8.670000
# ..           ...
# 195     7.530000
# 196     8.560000
# 197     8.940000
# 198     6.600000
# 199     8.350000
#
# [200 rows x 1 columns]

# %%
y
# Out:
#      student_marks
# 0            78.50
# 1            76.74
# 2            78.68
# 3            71.82
# 4            84.19
# ..             ...
# 195          81.67
# 196          84.68
# 197          86.75
# 198          78.05
# 199          83.50
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .2,random_state = 4)

# %%
x_train
# Out:
#      study_hours
# 26      6.510000
# 134     6.510000
# 180     6.970000
# 158     7.530000
# 189     7.260000
# ..           ...
# 104     7.230000
# 129     6.330000
# 183     8.610000
# 174     5.390000
# 122     6.995949
#
# [160 rows x 1 columns]

# %%
y_train
# Out:
#      student_marks
# 26           74.75
# 134          78.39
# 180          77.19
# 158          81.57
# 189          79.87
# ..             ...
# 104          77.55
# 129          74.49
# 183          83.87
# 174          73.02
# 122          76.83
#
# [160 rows x 1 columns]

# %%
x_test
# Out:
#      study_hours
# 11      8.560000
# 99      8.070000
# 128     6.380000
# 175     5.390000
# 1       6.560000
# 111     6.370000
# 90      7.520000
# 177     5.790000
# 88      5.330000
# 187     5.540000
# 61      7.260000
# 199     8.350000
# 191     5.220000
# 123     7.620000
# 184     5.220000
# 188     6.995949
# 33      8.780000
# 171     7.190000
# 138     8.710000
# 84      6.880000
# 81      7.940000
# 102     8.260000
# 147     5.920000
# 34      8.720000
# 47      5.010000
# 124     8.690000
# 112     6.920000
# 6       6.670000
# 14      8.190000
# 190     5.790000
# 80      8.340000
# 18      8.410000
# 167     5.070000
# 45      6.180000
# 153     5.240000
# 119     6.600000
# 100     6.240000
# 83      6.010000
# 181     5.550000
# 71      5.110000

# %%
y_test
# Out:
#      student_marks
# 11           83.88
# 99           82.30
# 128          77.01
# 175          71.11
# 1            76.74
# 111          75.04
# 90           79.56
# 177          73.64
# 88           71.85
# 187          72.01
# 61           79.41
# 199          83.50
# 191          70.51
# 123          79.53
# 184          71.50
# 188          77.27
# 33           84.35
# 171          77.63
# 138          85.98
# 84           77.29
# 81           82.93
# 102          82.99
# 147          74.34
# 34           83.08
# 47           70.11
# 124          83.57
# 112          76.38
# 6            76.99
# 14           83.08
# 190          73.14
# 80           84.00
# 18           82.50
# 167          70.79
# 45           72.96
# 153          70.78
# 119          75.55
# 100          75.18
# 83           75.36
# 181          71.83
# 71           71.79

# %%
from sklearn.linear_model import LinearRegression
SLR = LinearRegression()                                   # y` = b*x + a
SLR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
SLR.coef_  # b
# Out:
# array([[3.9129132]])

# %%
SLR.intercept_
# Out:
# array([50.56891419])

# %%
SLR.predict([[45]])
# Out:
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[226.65000811]])

# %%
y_pred=SLR.predict(x_test)

# %%
y_pred
# Out:
# array([[84.06345117],
#        [82.1461237 ],
#        [75.5333004 ],
#        [71.65951633],
#        [76.23762477],
#        [75.49417127],
#        [79.99402144],
#        [73.22468161],
#        [71.42474154],
#        [72.24645331],
#        [78.97666401],
#        [83.2417394 ],
#        [70.99432109],
#        [80.38531276],
#        [70.99432109],
#        [77.94345427],
#        [84.92429207],
#        [78.70276009],
#        [84.65038815],
#        [77.489757  ],
#        [81.63744499],
#        [82.88957721],
#        [73.73336033],
#        [84.68951728],
#        [70.17260932],
#        [84.57212989],
#        [77.64627353],
#        [76.66804523],
#        [82.61567329],
#        [73.22468161],
#        [83.20261027],
#        [83.47651419],
#        [70.40738411],
#        [74.75071776],
#        [71.07257935],
#        [76.3941413 ],
#        [74.98549255],
#        [74.08552252],
#        [72.28558244],
#        [70.56390064]])

# %%
pd.DataFrame(np.c_[x_test, y_test, y_pred], columns = ["study_hours", "student_marks_original","student_marks_predicted"])
# Out:
#     study_hours  student_marks_original  student_marks_predicted
# 0      8.560000                   83.88                84.063451
# 1      8.070000                   82.30                82.146124
# 2      6.380000                   77.01                75.533300
# 3      5.390000                   71.11                71.659516
# 4      6.560000                   76.74                76.237625
# 5      6.370000                   75.04                75.494171
# 6      7.520000                   79.56                79.994021
# 7      5.790000                   73.64                73.224682
# 8      5.330000                   71.85                71.424742
# 9      5.540000                   72.01                72.246453
# 10     7.260000                   79.41                78.976664
# 11     8.350000                   83.50                83.241739
# 12     5.220000                   70.51                70.994321
# 13     7.620000                   79.53                80.385313
# 14     5.220000                   71.50                70.994321
# 15     6.995949                   77.27                77.943454
# 16     8.780000                   84.35                84.924292
# 17     7.190000                   77.63                78.702760
# 18     8.710000                   85.98                84.650388
# 19     6.880000                   77.29                77.489757
# 20     7.940000                   82.93                81.637445
# 21     8.260000                   82.99                82.889577
# 22     5.920000                   74.34                73.733360
# 23     8.720000                   83.08                84.689517
# 24     5.010000                   70.11                70.172609
# 25     8.690000                   83.57                84.572130
# 26     6.920000                   76.38                77.646274
# 27     6.670000                   76.99                76.668045
# 28     8.190000                   83.08                82.615673
# 29     5.790000                   73.14                73.224682
# 30     8.340000                   84.00                83.202610
# 31     8.410000                   82.50                83.476514
# 32     5.070000                   70.79                70.407384
# 33     6.180000                   72.96                74.750718
# 34     5.240000                   70.78                71.072579
# 35     6.600000                   75.55                76.394141
# 36     6.240000                   75.18                74.985493
# 37     6.010000                   75.36                74.085523
# 38     5.550000                   71.83                72.285582
# 39     5.110000                   71.79                70.563901

# %%
SLR.score(x_test,y_test)
# Out:
# 0.9727715257951913

# %%
plt
